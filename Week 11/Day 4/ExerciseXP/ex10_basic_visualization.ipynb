# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.randint(0, 100, size=20)
print(data)
# Out:
# [45 99 46 74 54 39 42 52 84 87 27 85 67 74  1  9 41 21 32 30]

# %%
plt.plot(data, linestyle='dotted')
plt.show()
