# %%
import pandas as pd

file = (r'C:\Users\bbrow\Desktop\Courses\Developers Institute\Exercises\Week 9\Day 2\ExerciseXP\student-mental-health\Student Mental Health.csv')
stm_df = pd.read_csv(file)
stm_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %%
stm_df['Do you have Depression?'] = stm_df['Do you have Depression?'].map({'Yes': 1, 'No': 0})
stm_df['Do you have Anxiety?'] = stm_df['Do you have Anxiety?'].map({'Yes': 1, 'No': 0})
stm_df['Do you have Panic attack?'] = stm_df['Do you have Panic attack?'].map({'Yes': 1, 'No': 0})
stm_df['Did you seek any specialist for a treatment?'] = stm_df['Did you seek any specialist for a treatment?'].map({'Yes': 1, 'No': 0})

# %%
stm_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#    Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# 0                        1                     0                          1
# 1                        0                     1                          0
# 2                        1                     1                          1
# 3                        1                     0                          0
# 4                        0                     0                          0
#
#    Did you seek any specialist for a treatment?
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0

# %%
stm2_df = stm_df[['Age', 'What is your CGPA?', 'Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack?']]
stm2_df.head()
# Out:
#     Age What is your CGPA?  Do you have Depression?  Do you have Anxiety?  \
# 0  18.0        3.00 - 3.49                        1                     0
# 1  21.0        3.00 - 3.49                        0                     1
# 2  19.0        3.00 - 3.49                        1                     1
# 3  22.0        3.00 - 3.49                        1                     0
# 4  23.0        3.00 - 3.49                        0                     0
#
#    Do you have Panic attack?
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(stm2_df, hue='Age', markers=["o", "s", "D", "^", "v", "<", ">"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.pairplot(stm2_df, hue='Do you have Anxiety?', markers=["o", "s", "D", "^", "v", "<", ">"])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1609: UserWarning: The markers list has more values (7) than needed (2), which may not be intended.
#   hue = data.get(self._hue_var)
