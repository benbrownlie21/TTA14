# %%
import pandas as pd

file = (r'C:\Users\bbrow\Desktop\Courses\Developers Institute\Exercises\Week 9\Day 2\ExerciseXP\student-mental-health\Student Mental Health.csv')
stm_df = pd.read_csv(file)
stm_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %%
def midpoint(cgpa_range):
    low, high = map(float, cgpa_range.split(' - '))
    return (low + high) / 2

stm_df['CGPA_midpoint'] = stm_df['What is your CGPA?'].apply(midpoint)

# %%
stm_df.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?  CGPA_midpoint
# 0                                           No          3.245
# 1                                           No          3.245
# 2                                           No          3.245
# 3                                           No          3.245
# 4                                           No          3.245

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

g = sns.FacetGrid(stm_df, col="What is your CGPA?")
g = g.map(plt.hist, "Do you have Depression?", edgecolor ='w', linewidth=2)

g.fig.suptitle('Analyzing Distributions And Relationships', y=1.05, weight='bold')
plt.show()
